# %%
import cv2 as cv2
import numpy as np
from numpy import asarray
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Read image
img = Image.open('2.jpeg')
image_pixels=asarray(img)
# Output Images
fig, ax = plt.subplots(figsize=(8,4))
ax.imshow(img)
plt.show()

# %%
img = cv2.imread('2.jpeg')
plt.hist(img.ravel(),256,[0,256])
plt.plot(histr)

# %%
std=image_pixels.std()
mean=image_pixels.mean()        # calculating mean pixel intensity
print(image_pixels.max(),"max") #printing maximum intensities 
print(image_pixels.min(),"min") #printing minimum intensities
print(mean,"mean")              # printing mean intensities
# Out:
# 255 max
# 0 min
# 128.7380843757665 mean
